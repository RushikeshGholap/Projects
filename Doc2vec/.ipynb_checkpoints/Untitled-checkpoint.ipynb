# %%
import os
import PyPDF2

path = '/Users/akshay/Dropbox/Personal/Data Science/iPython/Large_Data'


f = []
for root, dirs, files in os.walk(path):
    f.append(files)
print(f)
# Out:
# [['.DS_Store'], [], ['Trident Trust SG - Asst Manager Trust Administration.pdf', 'Asst Finance Mgr - JD.pdf', 'CDL - EVP Head of Asset Mgt.docx', 'Citco - Hedge Fund Accountant JD.DOCX', 'Corp Sec Senior Executive JD.pdf', 'JD_Manager.pdf', 'Manager JD.docx', 'EQUIOM SG_Associate Director-JD.pdf', 'JD - Asst Finance Manager.docx', 'Citco- Fund Accountant (Private Equity) JD.DOCX', 'Job.txt', 'Asst Manager Trust Administration.docx', 'DCP HK JD_Sr. PE. Acct.jpg', 'Vistra - AM Funds Corp Sec role.jpg', 'Asst Manager Trust PDF.pdf', 'Job2.txt', 'JD - Para Legal cum Senior Office Admin.pdf'], ['a2.pdf', '3Carrie.pdf', 'a1.pdf', '8Holly.pdf', 'antiword.exe', '1Amy.docx', '8Holly.docx', '7Giraffe.doc', '10Jonas.doc', '9Ignatius.pdf', '4Dickson.doc', '5Edwardo.pdf', '10Jonas.pdf', '1Amy.pdf', '6Faye.docx', '7Giraffe.pdf', '5Edwardo.doc', '4Dickson.pdf', 'Major_Project_Report.pdf', '2Ben.docx', 'Hedge Fund Accountant JD.docx', '6Faye.pdf', '2Ben.pdf', '9Ignatius.docx', '3Carrie.docx'], ['Ful
# ...
