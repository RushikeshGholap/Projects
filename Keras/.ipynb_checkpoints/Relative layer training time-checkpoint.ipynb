# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
import missingno as msno

from keras.layers import Input, Dense, concatenate, Embedding, LSTM, Conv1D, Flatten, MaxPooling1D
from keras.layers import Dropout, BatchNormalization
from keras.models import Model, Sequential
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.regularizers import l1, l2

import time

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from keras.callbacks import Callback

# %%
df = pd.read_csv('job_skills.csv')
df.head(3)
# Out:
#   Company                                              Title  \
# 0  Google                       Google Cloud Program Manager
# 1  Google  Supplier Development Engineer (SDE), Cable/Con...
# 2  Google  Data Analyst, Product and Tools Operations, Go...
#
#                        Category                     Location  \
# 0            Program Management                    Singapore
# 1  Manufacturing & Supply Chain              Shanghai, China
# 2           Technical Solutions  New York, NY, United States
#
#                                     Responsibilities  \
# 0  Shape, shepherd, ship, and show technical prog...
# 1  Drive cross-functional activities in the suppl...
# 2  Collect and analyze data to draw insight and i...
#
#                               Minimum Qualifications  \
# 0  BA/BS degree or equivalent practical experienc...
# 1  BS degree in an Engineering discipline or equi...
# 2  Bachelor’s degree in Business, Economics, Stat...
#
#                             Preferred Qualifications
# 0  Experience in the business technology market a...
# 1  BSEE, BSME or BSIE degree.\nExperience of usin...
# 2  Experience partnering or consulting cross-func...

# %%
df.dropna(inplace=True)

# %%
msno.matrix(df)

# %%
def combine(i):
    return ' '.join(df.iloc[i,-3:]).replace("\n","")

# %%
X = [combine(i) for i in range(df.shape[0])]
y = df['Category']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, stratify=y, random_state=42)
print([len(i) for i in [X_train, X_test, y_train, y_test]])
# Out:
# [1049, 186, 1049, 186]

# %%
cnt = CountVectorizer(stop_words=None)
cnt.fit(X_train)
len(cnt.vocabulary_)
# Out:
# 5598

# %%
vocab_size = 5598

# %%
lbl = LabelEncoder()
y_train_lbl = lbl.fit_transform(y_train)

# %%
t = Tokenizer(num_words=vocab_size)
t.fit_on_texts(X_train)
seq = t.texts_to_sequences(X_train)
plt.hist([len(i) for i in seq])
# Out:
# (array([  2., 145., 343., 344., 138.,  42.,  32.,   2.,   0.,   1.]),
#  array([ 20. ,  74.4, 128.8, 183.2, 237.6, 292. , 346.4, 400.8, 455.2,
#         509.6, 564. ]),
#  <a list of 10 Patch objects>)

# %%
X_train_pad = pad_sequences(seq, maxlen=300, truncating='post', padding='post')
X_train_pad.shape
# Out:
# (1049, 300)

# %%
out_dims = len(np.unique(y_train))
inp_dims = X_train_pad.shape[1]

# %%
inp = Input((inp_dims,))
embed_out = Embedding(vocab_size, 256, input_length=inp_dims)(inp)

x = Conv1D(filters=32, kernel_size=3, activation='relu')(embed_out)
x = MaxPooling1D(pool_size=2)(x)
x = Flatten()(x)

x = Dense(64, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(32, activation='relu')(x)
x = Dropout(0.5)(x)
out = Dense(out_dims, activation='softmax')(x)

model = Model(inp, out)
model.summary()

model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['acc'])
model.fit(X_train_pad, y_train_lbl,      
          epochs=10, 
          batch_size=128, 
          validation_split=0.2, 
          verbose=1,
          callbacks = [time_callback])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 300)               0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 300, 256)          1433088
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 298, 32)           24608
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 149, 32)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4768)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                305216
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 23)                759
# =================================================================
# Total params: 1,765,751
# Trainable params: 1,765,751
# Non-trainable params: 0
# _________________________________________________________________
# Train on 839 samples, validate on 210 samples
# Epoch 1/10
# 839/839 [==============================] - 2s 3ms/step - loss: 3.0643 - acc: 0.0834 - val_loss: 2.8260 - val_acc: 0.2000
# Epoch 2/10
# 839/839 [==============================] - 1s 1ms/step - loss: 2.9350 - acc: 0.1097 - val_loss: 2.7357 - val_acc: 0.2143
# Epoch 3/10
# 839/839 [==============================] - 1s 1ms/step - loss: 2.7852 - acc: 0.1609 - val_loss: 2.6736 - val_acc: 0.3238
# Epoch 4/10
# 839/839 [==============================] - 2s 2ms/step - loss: 2.6518 - acc: 0.1847 - val_loss: 2.4820 - val_acc: 0.3238
# Epoch 5/10
# 839/839 [==============================] - 1s 1ms/step - loss: 2.5337 - acc: 0.2145 - val_loss: 2.4574 - val_acc: 0.4190
# Epoch 6/10
# 839/839 [==============================] - 1s 1ms/step - loss: 2.3290 - acc: 0.2694 - val_loss: 2.3104 - val_acc: 0.4333
# Epoch 7/10
# 839/839 [==============================] - 1s 2ms/step - loss: 2.2472 - acc: 0.3075 - val_loss: 2.1949 - val_acc: 0.4143
# Epoch 8/10
# 839/839 [==============================] - 1s 1ms/step - loss: 2.0978 - acc: 0.3397 - val_loss: 2.1199 - val_acc: 0.4762
# Epoch 9/10
# 839/839 [==============================] - 1s 1ms/step - loss: 1.9921 - acc: 0.3838 - val_loss: 1.9682 - val_acc: 0.4476
# Epoch 10/10
# 839/839 [==============================] - 1s 1ms/step - loss: 1.8767 - acc: 0.4124 - val_loss: 1.8828 - val_acc: 0.4667

# %%
#Callback class for time history (picked up this solution directly from stackoverflow)

class TimeHistory(Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)
        
time_callback = TimeHistory()

# %%
def get_average_layer_train_time(epochs):
    
    #Loop through each layer setting it Trainable and others as non trainable
    results = []
    for i in range(len(model.layers)):
        
        layer_name = model.layers[i].name    #storing name of layer for printing layer
        
        #Setting all layers as non-Trainable
        for layer in model.layers:
            layer.trainable = False
            
        #Setting ith layers as trainable
        model.layers[i].trainable = True
        
        #Compile
        model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['acc'])
        
        #Fit on a small number of epochs with callback that records time for each epoch
        model.fit(X_train_pad, y_train_lbl,      
              epochs=epochs, 
              batch_size=128, 
              validation_split=0.2, 
              verbose=0,
              callbacks = [time_callback])
        
        results.append(np.average(time_callback.times))
        #Print average of the time for each layer
        print(f"{layer_name}: Approx (avg) train time for {epochs} epochs = ", np.average(time_callback.times))
    return results

# %%
results = get_average_layer_train_time(5)
# Out:
# input_1: Approx (avg) train time for 5 epochs =  0.3849788188934326
# embedding_1: Approx (avg) train time for 5 epochs =  0.9412121772766113
# conv1d_1: Approx (avg) train time for 5 epochs =  0.8409868717193604
# max_pooling1d_1: Approx (avg) train time for 5 epochs =  0.41693410873413084
# flatten_1: Approx (avg) train time for 5 epochs =  0.39940581321716306
# dense_1: Approx (avg) train time for 5 epochs =  0.4275023937225342
# dropout_1: Approx (avg) train time for 5 epochs =  0.39661059379577634
# dense_2: Approx (avg) train time for 5 epochs =  0.41174969673156736
# dropout_2: Approx (avg) train time for 5 epochs =  0.3961236000061035
# dense_3: Approx (avg) train time for 5 epochs =  0.41192827224731443

# %%
plt.plot(results)
