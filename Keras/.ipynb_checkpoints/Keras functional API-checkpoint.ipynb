# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import missingno as msno

from keras.layers import Input, Dense, concatenate
from keras.layers import Dropout, BatchNormalization
from keras.models import Model

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('job_skills.csv')
df.head(3)
# Out:
#   Company                                              Title  \
# 0  Google                       Google Cloud Program Manager
# 1  Google  Supplier Development Engineer (SDE), Cable/Con...
# 2  Google  Data Analyst, Product and Tools Operations, Go...
#
#                        Category                     Location  \
# 0            Program Management                    Singapore
# 1  Manufacturing & Supply Chain              Shanghai, China
# 2           Technical Solutions  New York, NY, United States
#
#                                     Responsibilities  \
# 0  Shape, shepherd, ship, and show technical prog...
# 1  Drive cross-functional activities in the suppl...
# 2  Collect and analyze data to draw insight and i...
#
#                               Minimum Qualifications  \
# 0  BA/BS degree or equivalent practical experienc...
# 1  BS degree in an Engineering discipline or equi...
# 2  Bachelor’s degree in Business, Economics, Stat...
#
#                             Preferred Qualifications
# 0  Experience in the business technology market a...
# 1  BSEE, BSME or BSIE degree.\nExperience of usin...
# 2  Experience partnering or consulting cross-func...

# %%
df.dropna(inplace=True)

# %%
msno.matrix(df)

# %%
cnt = TfidfVectorizer(stop_words='english', lowercase=True, strip_accents='ascii')
lbl = LabelEncoder()

# %%
def combine(i):
    return ' '.join(df.iloc[i,-3:]).replace("\n","")

# %%
all_text = [combine(i) for i in range(df.shape[0])]
responsibilities = df['Responsibilities']
qualifications = df['Minimum Qualifications']
preferred = df['Preferred Qualifications']

# %%
category = df['Category']

# %%
full_txt = cnt.fit_transform(all_text)
len(cnt.vocabulary_)
# Out:
# 5647

# %%
category_dims = len(np.unique(category))
category_dims
# Out:
# 23

# %%
responsibilities = cnt.transform(responsibilities)
qualifications = cnt.transform(qualifications)
preferred = cnt.transform(preferred)

# %%
category = lbl.fit_transform(category)

# %% [markdown]
# # Functional model with Multi-inputs

# %%
from keras.preprocessing.text import Tokenizer

# %%
t = token

# %%
resp = Input((responsibilities.shape[1],))


qual = Input((qualifications.shape[1],))

pref = Input((preferred.shape[1],))




x = concatenate([a, b, c])
x = BatchNormalization(momentum=0.7)(inp)
x = Dense(64, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.5)(x)
aux_out = Dense(category_dims, activation='softmax')(x)

model = Model(inp, aux_out)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_41 (InputLayer)        (None, 5647)              0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 5647)              22588
# _________________________________________________________________
# dense_69 (Dense)             (None, 64)                361472
# _________________________________________________________________
# dropout_50 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_70 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_51 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_71 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_52 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_72 (Dense)             (None, 23)                1495
# =================================================================
# Total params: 393,875
# Trainable params: 382,581
# Non-trainable params: 11,294
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])
model.fit(full_txt, category, 
          epochs=100, 
          batch_size=128, 
          validation_split=0.3, 
          verbose=0)

# %%
plt.plot(model.history.history.get('acc'),'r')
plt.plot(model.history.history.get('val_acc'),'g')

# %%
plt.plot(model.history.history.get('loss'),'r')
plt.plot(model.history.history.get('val_loss'),'g')
