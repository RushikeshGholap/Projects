# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
import missingno as msno

from keras.layers import Input, Dense, concatenate, Embedding, LSTM, Conv1D, Flatten, MaxPooling1D
from keras.layers import Dropout, BatchNormalization
from keras.models import Model, Sequential
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.regularizers import l1, l2

import time

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('job_skills.csv')
df.head(3)
# Out:
#   Company                                              Title  \
# 0  Google                       Google Cloud Program Manager
# 1  Google  Supplier Development Engineer (SDE), Cable/Con...
# 2  Google  Data Analyst, Product and Tools Operations, Go...
#
#                        Category                     Location  \
# 0            Program Management                    Singapore
# 1  Manufacturing & Supply Chain              Shanghai, China
# 2           Technical Solutions  New York, NY, United States
#
#                                     Responsibilities  \
# 0  Shape, shepherd, ship, and show technical prog...
# 1  Drive cross-functional activities in the suppl...
# 2  Collect and analyze data to draw insight and i...
#
#                               Minimum Qualifications  \
# 0  BA/BS degree or equivalent practical experienc...
# 1  BS degree in an Engineering discipline or equi...
# 2  Bachelor’s degree in Business, Economics, Stat...
#
#                             Preferred Qualifications
# 0  Experience in the business technology market a...
# 1  BSEE, BSME or BSIE degree.\nExperience of usin...
# 2  Experience partnering or consulting cross-func...

# %%
df.dropna(inplace=True)

# %%
msno.matrix(df)

# %%
def combine(i):
    return ' '.join(df.iloc[i,-3:]).replace("\n","")

# %%
X = [combine(i) for i in range(df.shape[0])]
y = df['Category']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, stratify=y, random_state=42)
print([len(i) for i in [X_train, X_test, y_train, y_test]])
# Out:
# [1049, 186, 1049, 186]

# %% [markdown]
# # Functional model with Multi-inputs

# %%
cnt = CountVectorizer(stop_words=None)
cnt.fit(X_train)
len(cnt.vocabulary_)
# Out:
# 5598

# %%
vocab_size = 5598

# %%
lbl = LabelEncoder()
y_train_lbl = lbl.fit_transform(y_train)

# %%
t = Tokenizer(num_words=vocab_size)
t.fit_on_texts(X_train)
seq = t.texts_to_sequences(X_train)
plt.hist([len(i) for i in seq])
X_train_pad = pad_sequences(seq, maxlen=300, truncating='post', padding='post')
X_train_pad.shape
# Out:
# (1049, 300)

# %%
out_dims = len(np.unique(y_train))
inp_dims = X_train_pad.shape[1]

# %%
inp = Input((inp_dims,))
embed_out = Embedding(vocab_size, 64, input_length=inp_dims)(inp)

x = Conv1D(filters=32, kernel_size=1, activation='relu')(embed_out)
x = MaxPooling1D(pool_size=2)(x)
x = Flatten()(x)

x = Dense(32, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(32, activation='relu')(x)
x = Dropout(0.5)(x)
out = Dense(out_dims, activation='softmax')(x)

model = Model(inp, out)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_16 (InputLayer)        (None, 300)               0
# _________________________________________________________________
# embedding_16 (Embedding)     (None, 300, 64)           358272
# _________________________________________________________________
# conv1d_16 (Conv1D)           (None, 300, 32)           2080
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 150, 32)           0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 4800)              0
# _________________________________________________________________
# dense_46 (Dense)             (None, 32)                153632
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_47 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_48 (Dense)             (None, 23)                759
# =================================================================
# Total params: 515,799
# Trainable params: 515,799
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])
model.fit(X_train_pad, y_train_lbl,      
          epochs=100, 
          batch_size=128, 
          validation_split=0.2, 
          verbose=0,
          callbacks = [time_callback])

# %%
plt.plot(model.history.history.get('acc'),'r')
plt.plot(model.history.history.get('val_acc'),'g')

# %%
plt.plot(model.history.history.get('loss'),'r')
plt.plot(model.history.history.get('val_loss'),'g')

# %%
weights = model.layers[1]

# %%
embedding_weights = weights.get_weights()[0]

# %%
embedding_weights.shape
# Out:
# (5598, 64)

# %%
t.index_word
# Out:
# {1: 'and',
#  2: 'to',
#  3: 'in',
#  4: 'experience',
#  5: 'with',
#  6: 'of',
#  7: 'the',
#  8: 'or',
#  9: 'a',
#  10: 'ability',
#  11: 'business',
#  12: 'for',
#  13: 'as',
#  14: 'skills',
#  15: 'management',
#  16: 'work',
#  17: 'degree',
#  18: 'technical',
#  19: 'on',
#  20: 'google',
#  21: 'product',
#  22: 'equivalent',
#  23: 'teams',
#  24: 'sales',
#  25: 'practical',
#  26: 'data',
#  27: 'cloud',
#  28: 'team',
#  29: 'years',
#  30: 'customer',
#  31: 'bs',
#  32: 'working',
#  33: 'ba',
#  34: 'develop',
#  35: 'marketing',
#  36: 'design',
#  37: 'partners',
#  38: 'manage',
#  39: 'an',
#  40: 'related',
#  41: 'engineering',
#  42: 'including',
#  43: 'strategic',
#  44: 'development',
#  45: 'partner',
#  46: 'drive',
#  47: 'communication',
#  48: 'environment',
#  49: 'demonstrated',
#  50: 'cross',
#  51: 'that',
#  52: 'across',
#  53: 'technology',
#  54: 'support',
#  55: 'solutions',
#  56: 'relationships',
#  57: 'excellent',
#  58: 'field',
#  59: 'functional',
#  60: 'our',
#  61: 'projects',
#  62: 'program',
#  63: 'strong',
#  64: 'analytical',
#  65: 'be',
#  66: 'products',
#  67: 'new',
#  68: 'analysis',
#  69: 'project',
#  70: 'at',
#  71: 'provide',
#  72: 'industry',
#  73: 'build',
#  74: 'complex',
#  75: 'customers',
#  76: 'strategy',
#  77: 'their',
#  78: 'computer',
#  79: 'knowledge',
#  80: 'science',
#  81: 'understanding',
#  82: 'software',
#  83: 'lead',
#  84: 'stakeholders',
#  85: 'identify',
#  86: 'service',
#  87: 'other',
#  88: 'operations',
#  89: 'systems',
#  90: 'managing',
#  91: 'through',
#  92: 'multiple',
#  93: 'internal',
#  94: 'platform',
#  95: 'effective',
#  96: 'opportunities',
#  97: 'market',
#  98: 'technologies',
#  99: 'by',
#  100: 'research',
#  101: 'all',
#  102: 'deliver',
#  103: 'process',
#  104: 'relevant',
#  105: 'g',
#  106: 'your',
#  107: 'key',
#  108: 'performance',
#  109: 'goals',
#  110: 'from',
#  111: 'e',
#  112: 'consulting',
#  113: 'global',
#  114: 'client',
#  115: 'ensure',
#  116: 'advertising',
#  117: 'processes',
#  118: 'high',
#  119: 'write',
#  120: 'leadership',
#  121: 'speak',
#  122: 'are',
#  123: 'time',
#  124: 'within',
#  125: 'implement',
#  126: 'issues',
#  127: 'english',
#  128: 'level',
#  129: 'written',
#  130: 'organizational',
#  131: 'media',
#  132: 'fluently',
#  133: '2018',
#  134: 'programs',
#  135: 'idiomatically',
#  136: 'strategies',
#  137: 'clients',
#  138: 'services',
#  139: 'effectively',
#  140: 'mobile',
#  141: 'interpersonal',
#  142: 'help',
#  143: 'such',
#  144: 'fast',
#  145: 'initiatives',
#  146: 'tools',
#  147: 'web',
#  148: 'user',
#  149: 'communicate',
#  150: 'well',
#  151: 'understand',
#  152: 'mba',
#  153: 'paced',
#  154: 'etc',
#  155: 'large',
#  156: 'google’s',
#  157: 'growth',
#  158: 'infrastructure',
#  159: 'developing',
#  160: 'improve',
#  161: 'solving',
#  162: 'problem',
#  163: 'recommendations',
#  164: 'interest',
#  165: 'planning',
#  166: 'insights',
#  167: 'account',
#  168: 'plans',
#  169: 'role',
#  170: 'needs',
#  171: 'legal',
#  172: 'full',
#  173: 'both',
#  174: 'communications',
#  175: 'quality',
#  176: 'based',
#  177: 'operational',
#  178: 'requirements',
#  179: 'activities',
#  180: 'external',
#  181: 'online',
#  182: 'them',
#  183: 'platforms',
#  184: 'create',
#  185: 'enterprise',
#  186: 'verbal',
#  187: 'maintain',
#  188: 'influence',
#  189: 'analytics',
#  190: 'using',
#  191: '5',
#  192: 'c',
#  193: 'best',
#  194: 'into',
#  195: 'it',
#  196: 'building',
#  197: 'creative',
#  198: 'scale',
#  199: 'organization',
#  200: 'presentations',
#  201: 'finance',
#  202: 'up',
#  203: 'leading',
#  204: 'information',
#  205: 'is',
#  206: 'problems',
#  207: 'between',
#  208: 'closely',
#  209: 'while',
#  210: 'implementation',
#  211: 'make',
#  212: 'digital',
#  213: 'presentation',
#  214: "master's",
#  215: 'executive',
#  216: 'levels',
#  217: 'practices',
#  218: '10',
#  219: 'training',
#  220: 'internship',
#  221: 'results',
#  222: 'collaborate',
#  223: 'end',
#  224: 'analyze',
#  225: 'content',
#  226: 'detail',
#  227: 'complete',
#  228: 'define',
#  229: 'security',
#  230: 'proven',
#  231: 'python',
#  232: 'areas',
#  233: 'able',
#  234: 'solution',
#  235: 'corporate',
#  236: 'trends',
#  237: '2019',
#  238: 'track',
#  239: 'metrics',
#  240: 'required',
#  241: 'specific',
#  242: 'financial',
#  243: 'interaction',
#  244: 'challenges',
#  245: 'travel',
#  246: 'highly',
#  247: 'senior',
#  248: 'plan',
#  249: 'how',
#  250: 'accounting',
#  251: 'impact',
#  252: 'one',
#  253: 'execute',
#  254: 'system',
#  255: 'existing',
#  256: 'can',
#  257: 'portfolio',
#  258: 'agency',
#  259: "google's",
#  260: 'events',
#  261: 'delivery',
#  262: "bachelor's",
#  263: 'search',
#  264: 'managers',
#  265: 'expertise',
#  266: 'computing',
#  267: 'sql',
#  268: 'internet',
#  269: 'people',
#  270: 'quantitative',
#  271: 'regional',
#  272: '4',
#  273: 'javascript',
#  274: 'agreements',
#  275: 'campaigns',
#  276: 'optimize',
#  277: 'engage',
#  278: 'visual',
#  279: 'consumer',
#  280: 'ideas',
#  281: 'execution',
#  282: 'value',
#  283: 'include',
#  284: 'given',
#  285: 'audiences',
#  286: 'statistics',
#  287: 'company',
#  288: 'channel',
#  289: 'record',
#  290: 'self',
#  291: 'responsibilities',
#  292: 'supply',
#  293: 'changing',
#  294: 'writing',
#  295: 'date',
#  296: 'resources',
#  297: 'interns',
#  298: '3',
#  299: 'iaas',
#  300: 'change',
#  301: 'responsibility',
#  302: 'ad',
#  303: 'serve',
#  304: 'advocate',
#  305: 'success',
#  306: 'solve',
#  307: 'application',
#  308: 'scalable',
#  309: 'more',
#  310: 'paas',
#  311: 'ongoing',
#  312: 'providing',
#  313: 'currently',
#  314: 'suite',
#  315: 'achieve',
#  316: 'oriented',
#  317: 'delivering',
#  318: 'compliance',
#  319: 'reviews',
#  320: 'priorities',
#  321: 'various',
#  322: 'engineers',
#  323: 'towards',
#  324: 'environments',
#  325: 'brand',
#  326: 'year',
#  327: 'java',
#  328: 'executives',
#  329: 'assigned',
#  330: 'june',
#  331: 'prioritize',
#  332: 'use',
#  333: 'conduct',
#  334: 'meet',
#  335: 'production',
#  336: 'term',
#  337: 'facing',
#  338: 'partnerships',
#  339: 'judgment',
#  340: 'hardware',
#  341: 'reporting',
#  342: 'day',
#  343: 'december',
#  344: 'present',
#  345: 'range',
#  346: 'agencies',
#  347: 'go',
#  348: 'collaboration',
#  349: 'saas',
#  350: 'background',
#  351: 'relationship',
#  352: 'policies',
#  353: 'supporting',
#  354: 'practice',
#  355: 'attention',
#  356: 'must',
#  357: 'operate',
#  358: 'act',
#  359: 'local',
#  360: 'risk',
#  361: 'chain',
#  362: 'will',
#  363: 'independent',
#  364: 'take',
#  365: 'order',
#  366: '2',
#  367: 'big',
#  368: 'ux',
#  369: 'prepare',
#  370: 'graduating',
#  371: 'public',
#  372: 'concepts',
#  373: 'vendor',
#  374: 'hr',
#  375: 'approach',
#  376: 'driven',
#  377: 'familiarity',
#  378: 'network',
#  379: 'united',
#  380: 'states',
#  381: 'policy',
#  382: 'statistical',
#  383: 'successful',
#  384: 'graduation',
#  385: 'standards',
#  386: 'professional',
#  387: 'talent',
#  388: 'multi',
#  389: 'long',
#  390: 'members',
#  391: 'language',
#  392: 'improvements',
#  393: 'focus',
#  394: 'advice',
#  395: '6',
#  396: 'languages',
#  397: 'deep',
#  398: 'vendors',
#  399: 'integration',
#  400: 'ecosystem',
#  401: 'focused',
#  402: 'thinking',
#  403: 'models',
#  404: 'about',
#  405: 'effectiveness',
#  406: 'objectives',
#  407: 'capabilities',
#  408: 'enrolled',
#  409: 'findings',
#  410: 'fields',
#  411: 'test',
#  412: 'have',
#  413: 'competitive',
#  414: 'documentation',
#  415: 'functionally',
#  416: 'programming',
#  417: 'quickly',
#  418: 'manager',
#  419: 'architectures',
#  420: 'passion',
#  421: 'may',
#  422: 'territory',
#  423: 'partnership',
#  424: 'applications',
#  425: 'trusted',
#  426: 'base',
#  427: 'simultaneously',
#  428: 'perform',
#  429: 'making',
#  430: 'adoption',
#  431: 'student',
#  432: 'non',
#  433: 'human',
#  434: 'basis',
#  435: 'week',
#  436: 'pipeline',
#  437: 'start',
#  438: 'reports',
#  439: 'investment',
#  440: 'contribute',
#  441: 'education',
#  442: 'cycle',
#  443: 'feedback',
#  444: 'advertisers',
#  445: 'following',
#  446: 'handle',
#  447: 'maintaining',
#  448: 'android',
#  449: 'critical',
#  450: 'resolve',
#  451: 'code',
#  452: 'contact',
#  453: 'variety',
#  454: 'law',
#  455: 'users',
#  456: 'when',
#  457: 'efficiency',
#  458: 'risks',
#  459: 'returning',
#  460: 'demonstrate',
#  461: 'implementing',
#  462: 'outstanding',
#  463: 'html',
#  464: 'techniques',
#  465: 'groups',
#  466: 'advise',
#  467: 'grow',
#  468: 'individual',
#  469: 'accounts',
#  470: 'review',
#  471: 'leaders',
#  472: 'guidance',
#  473: 'cost',
#  474: 'meaningful',
#  475: 'decision',
#  476: 'engagement',
#  477: 'innovative',
#  478: 'capacity',
#  479: 'broad',
#  480: 'any',
#  481: 'ms',
#  482: 'area',
#  483: 'campaign',
#  484: 'successfully',
#  485: 'modeling',
#  486: 'authorization',
#  487: 'coordinate',
#  488: 'features',
#  489: 'staffing',
#  490: 'video',
#  491: 'similar',
#  492: 'overall',
#  493: 'space',
#  494: 'status',
#  495: 'establish',
#  496: 'optimization',
#  497: 'designing',
#  498: 'setting',
#  499: 'efforts',
#  500: 'aspects',
#  501: 'architecture',
#  502: 'opportunity',
#  503: 'measurement',
#  504: 'proactively',
#  505: 'needed',
#  506: 'dynamic',
#  507: 'learn',
#  508: 'detailed',
#  509: 'functions',
#  510: 'direct',
#  511: 'others',
#  512: 'ways',
#  513: 'influencing',
#  514: 'emerging',
#  515: 'methodologies',
#  516: 'contribution',
#  517: 'potential',
#  518: 'necessary',
#  519: 'set',
#  520: 'they',
#  521: 'who',
#  522: 'principles',
#  523: 'documents',
#  524: 'learning',
#  525: 'different',
#  526: 'compelling',
#  527: 'share',
#  528: 'clear',
#  529: 'methods',
#  530: 'testing',
#  531: 'out',
#  532: 'expected',
#  533: 'phd',
#  534: 'matters',
#  535: 'creating',
#  536: 'offerings',
#  537: 'pursuing',
#  538: 'developer',
#  539: 'administration',
#  540: 'networking',
#  541: 'minimum',
#  542: 'office',
#  543: 'collaboratively',
#  544: 'wide',
#  545: 'ambiguous',
#  546: 'control',
#  547: 'improvement',
#  548: 'studies',
#  549: 'third',
#  550: 'retail',
#  551: 'upon',
#  552: 'around',
#  553: 'against',
#  554: 'messaging',
#  555: 'decisions',
#  556: 'assist',
#  557: 'linux',
#  558: 'requests',
#  559: 'sets',
#  560: 'materials',
#  561: '8',
#  562: 'emea',
#  563: 'youtube',
#  564: 'hiring',
#  565: 'during',
#  566: 'consultative',
#  567: 'advanced',
#  568: 'determined',
#  569: 'direction',
#  570: 'social',
#  571: 'changes',
#  572: 'troubleshooting',
#  573: 'which',
#  574: 'launch',
#  575: 'constantly',
#  576: 'leverage',
#  577: 'point',
#  578: 'manufacturing',
#  579: 'completing',
#  580: 'recruiting',
#  581: 'distributed',
#  582: 'responsible',
#  583: 'apply',
#  584: 'solid',
#  585: 'coordination',
#  586: 'lot',
#  587: 'increase',
#  588: 'tax',
#  589: 'flexibility',
#  590: 'beginning',
#  591: 'think',
#  592: 'vertical',
#  593: 'so',
#  594: 'experiences',
#  595: 'firm',
#  596: 'identifying',
#  597: 'via',
#  598: 'please',
#  599: 'adwords',
#  600: 'quarterly',
#  601: 'thorough',
#  602: 'designs',
#  603: 'resume',
#  604: 'throughout',
#  605: 'intelligence',
#  606: 'r',
#  607: 'international',
#  608: 'independently',
#  609: 'consult',
#  610: 'analyses',
#  611: 'organized',
#  612: 'serving',
#  613: 'engineer',
#  614: 'analyzing',
#  615: 'life',
#  616: 'briefings',
#  617: 'navigate',
#  618: '12',
#  619: 'diverse',
#  620: 'meetings',
#  621: 'evaluate',
#  622: 'graphic',
#  623: 'party',
#  624: 'entire',
#  625: 'selling',
#  626: 'proficiency',
#  627: 'apps',
#  628: 'site',
#  629: 'vision',
#  630: 'consistently',
#  631: 'oral',
#  632: 'sap',
#  633: 'major',
#  634: 'structure',
#  635: 'tracking',
#  636: 'display',
#  637: 'starter',
#  638: 'candidates',
#  639: 'strategically',
#  640: 'commercial',
#  641: 'scripting',
#  642: 'evolving',
#  643: 'shape',
#  644: 'directly',
#  645: 'concept',
#  646: 'leveraging',
#  647: 'core',
#  648: 'leads',
#  649: 'driving',
#  650: 'sourcing',
#  651: 'organizations',
#  652: 'position',
#  653: 'close',
#  654: 'consistent',
#  655: 'css',
#  656: 'buying',
#  657: 'region',
#  658: 'email',
#  659: 'if',
#  660: 'educate',
#  661: 'primary',
#  662: 'channels',
#  663: 'audience',
#  664: 'automation',
#  665: 'completion',
#  666: 'combined',
#  667: 'action',
#  668: 'top',
#  669: 'architect',
#  670: 'ensuring',
#  671: 'demand',
#  672: '11',
#  673: 'prototype',
#  674: 'doubleclick',
#  675: 'appropriate',
#  676: 'integrations',
#  677: 'tech',
#  678: 'challenging',
#  679: 'satisfaction',
#  680: 'relations',
#  681: 'german',
#  682: 'hands',
#  683: 'assets',
#  684: 'part',
#  685: 'machine',
#  686: 'database',
#  687: 'exceptional',
#  688: 'landscape',
#  689: 'advisor',
#  690: 'collaborating',
#  691: 'first',
#  692: 'good',
#  693: 'house',
#  694: 'integrators',
#  695: 'interact',
#  696: 'right',
#  697: 'thought',
#  698: 'negotiation',
#  699: 'joint',
#  700: '7',
#  701: 'agreement',
#  702: 'maximize',
#  703: 'crm',
#  704: 'engagements',
#  705: 'contract',
#  706: 'bid',
#  707: 'expert',
#  708: 'get',
#  709: 'current',
#  710: 'electrical',
#  711: 'businesses',
#  712: 'sense',
#  713: 'produce',
#  714: 'deliverables',
#  715: 'defined',
#  716: 'this',
#  717: 'pr',
#  718: 'usability',
#  719: 'interface',
#  720: 'behavior',
#  721: 'ambiguity',
#  722: 'comprehensive',
#  723: 'audit',
#  724: 'motivated',
#  725: 'goal',
#  726: 'thinker',
#  727: 'voice',
#  728: 'event',
#  729: 'procedures',
#  730: 'regarding',
#  731: 'presenting',
#  732: 'storage',
#  733: 'promote',
#  734: 'timelines',
#  735: 'mathematics',
#  736: 'standard',
#  737: 'launches',
#  738: 'communicating',
#  739: 'taking',
#  740: 'each',
#  741: 'generation',
#  742: 'proposition',
#  743: 'designers',
#  744: 'candidate',
#  745: 'productivity',
#  746: 'skill',
#  747: 'educational',
#  748: 'operating',
#  749: 'markets',
#  750: 'determine',
#  751: 'inform',
#  752: 'qualify',
#  753: 'proactive',
#  754: 'accountability',
#  755: 'investigations',
#  756: 'intern',
#  757: 'leader',
#  758: 'effort',
#  759: 'you',
#  760: 'assess',
#  761: 'university',
#  762: 'internally',
#  763: 'spreadsheet',
#  764: 'align',
#  765: 'member',
#  766: 'priority',
#  767: 'resource',
#  768: 'coach',
#  769: 'creation',
#  770: 'interview',
#  771: 'consultant',
#  772: 'actionable',
#  773: 'industrial',
#  774: 'common',
#  775: 'associated',
#  776: 'collaborative',
#  777: 'july',
#  778: 'salesforce',
#  779: 'live',
#  780: 'personal',
#  781: 'databases',
#  782: 'previous',
#  783: 'competing',
#  784: 'sciences',
#  785: 'highlight',
#  786: 's',
#  787: 'regular',
#  788: 'touch',
#  789: 'cultivate',
#  790: 'consultation',
#  791: 'controls',
#  792: 'supplier',
#  793: 'continuous',
#  794: 'monitor',
#  795: 'initiative',
#  796: 'own',
#  797: 'resolution',
#  798: 'ios',
#  799: 'guide',
#  800: 'future',
#  801: 'these',
#  802: 'address',
#  803: 'offer',
#  804: 'task',
#  805: 'protocols',
#  806: 'discussions',
#  807: 'psychology',
#  808: 'applied',
#  809: 'device',
#  810: 'partnering',
#  811: 'interested',
#  812: 'accurately',
#  813: 'colleagues',
#  814: 'participate',
#  815: 'keep',
#  816: 'lifecycle',
#  817: 'tailor',
#  818: 'privacy',
#  819: 'commit',
#  820: 'sensitive',
#  821: 'frameworks',
#  822: 'unix',
#  823: 'automate',
#  824: 'stakeholder',
#  825: 'press',
#  826: 'productive',
#  827: 'roles',
#  828: 'schedule',
#  829: 'proof',
#  830: 'demonstrations',
#  831: 'white',
#  832: 'we',
#  833: 'innovation',
#  834: 'impeccable',
#  835: 'difficult',
#  836: 'exchange',
#  837: 'matter',
#  838: 'timely',
#  839: 'country',
#  840: 'survey',
#  841: 'conducting',
#  842: 'proposals',
#  843: 'advertiser',
#  844: 'become',
#  845: 'identity',
#  846: 'access',
#  847: 'particular',
#  848: 'government',
#  849: 'balancing',
#  850: 'months',
#  851: 'healthcare',
#  852: 'not',
#  853: 'subject',
#  854: 'motivation',
#  855: 'prioritizing',
#  856: 'model',
#  857: 'distinctive',
#  858: 'distribution',
#  859: 'merchandising',
#  860: 'structures',
#  861: 'interests',
#  862: 'forecast',
#  863: 'i',
#  864: 'updates',
#  865: 'students',
#  866: 'weeks',
#  867: 'certification',
#  868: '2020',
#  869: 'slide',
#  870: 'papers',
#  871: 'dynamics',
#  872: 'spanish',
#  873: 'bring',
#  874: 'experiments',
#  875: 'motivate',
#  876: 'activity',
#  877: 'traditional',
#  878: 'deadlines',
#  879: 'actively',
#  880: 'domain',
#  881: 'app',
#  882: 'acquisition',
#  883: 'hci',
#  884: 'procurement',
#  885: 'open',
#  886: 'sure',
#  887: 'master',
#  888: 'enhance',
#  889: 'report',
#  890: 'networks',
#  891: 'implementations',
#  892: 'drivers',
#  893: 'architecting',
#  894: 'ip',
#  895: 'input',
#  896: 'providers',
#  897: 'deployment',
#  898: 'health',
#  899: 'response',
#  900: 'ownership',
#  901: 'coaching',
#  902: 'matrixed',
#  903: 'ads',
#  904: 'growing',
#  905: 'style',
#  906: 'along',
#  907: 'measure',
#  908: 'sector',
#  909: 'efficient',
#  910: 'performing',
#  911: 'budgets',
#  912: 'two',
#  913: 'explore',
#  914: 'com',
#  915: 'liaison',
#  916: 'recruit',
#  917: 'budget',
#  918: 'forecasting',
#  919: 'wider',
#  920: 'play',
#  921: 'motion',
#  922: 'further',
#  923: '1',
#  924: 'phone',
#  925: 'generate',
#  926: 'acumen',
#  927: 'engaging',
#  928: 'visualization',
#  929: 'employment',
#  930: 'onsite',
#  931: 'september',
#  932: 'basic',
#  933: 'influential',
#  934: 'alignment',
#  935: 'rapidly',
#  936: 'tasks',
#  937: 'influencers',
#  938: 'after',
#  939: 'outside',
#  940: 'mandarin',
#  941: 'trial',
#  942: 'clearly',
#  943: 'give',
#  944: 'established',
#  945: 'economics',
#  946: 'those',
#  947: 'hoc',
#  948: 'annual',
#  949: 'lasting',
#  950: 'regulatory',
#  951: 'collect',
#  952: 'translate',
#  953: 'depth',
#  954: 'generating',
#  955: 'inside',
#  956: 'speed',
#  957: 'property',
#  958: 'state',
#  959: 'safety',
#  960: 'dashboards',
#  961: 'scaled',
#  962: 'regions',
#  963: 'comfort',
#  964: 'willingness',
#  965: 'responses',
#  966: 'whiteboard',
#  967: 'apis',
#  968: 'broader',
#  969: 'stage',
#  970: 'reference',
#  971: 'significant',
#  972: 'topics',
#  973: 'analysts',
#  974: 'speaking',
#  975: 'organize',
#  976: 'comfortable',
#  977: 'real',
#  978: 'increasing',
#  979: 'employee',
#  980: 'function',
#  981: 'readiness',
#  982: 'mechanical',
#  983: 'electronics',
#  984: 'points',
#  985: 'prior',
#  986: 'load',
#  987: 'intellectual',
#  988: 'agile',
#  989: 'rfi',
#  990: 'integrity',
#  991: 'includes',
#  992: 'staff',
#  993: 'progress',
#  994: 'suggestions',
#  995: 'prototypes',
#  996: 'executing',
#  997: 'programmatic',
#  998: 'entertainment',
#  999: 'devices',
#  1000: 'story',
#  ...}

# %%
embedding_weights[27+1]
# Out:
# array([-0.06446671, -0.03790285,  0.00464766,  0.00732889,  0.04599596,
#         0.04441966,  0.00294467,  0.08279962, -0.01648405,  0.06494443,
#         0.01748945, -0.12429929, -0.02298587,  0.06320558, -0.08490311,
#        -0.04687005, -0.01490074,  0.05785559,  0.04139211,  0.04202342,
#        -0.02574907,  0.02785121,  0.03784971, -0.02958203, -0.0668525 ,
#        -0.0081844 ,  0.02862274,  0.02927868, -0.02630008, -0.06375019,
#        -0.00915334, -0.01768205, -0.04343663,  0.00629392, -0.06922313,
#        -0.00890187, -0.09150637, -0.01260222,  0.02053147,  0.03612765,
#         0.00626791,  0.07016405, -0.1203931 , -0.02451925,  0.02261953,
#         0.06228957, -0.01196355, -0.04817693, -0.01826351,  0.0063201 ,
#        -0.00406912, -0.07484844, -0.0599525 , -0.00050265,  0.02573328,
#         0.00552774,  0.01268331,  0.05866851, -0.00075833,  0.00988274,
#        -0.08295964,  0.11340302,  0.02679862, -0.06023546], dtype=float32)

# %%
dots = np.dot(embedding_weights, embedding_weights.T)
dots.shape
# Out:
# (5598, 5598)

# %%
def get_nearest_words(word,num = 10):
    pos = t.word_index.get(word)
    row = dots[pos-1]
    sorted_indexes = np.argsort(row)
    tops = sorted_indexes[-num:]
    bottoms = sorted_indexes[:num]
    
    
    top_words = [t.index_word.get(i) for i in tops]
    bottom_words = [t.index_word.get(i) for i in bottoms]
    
    return top_words, bottom_words

# %%
t.index_word
# Out:
# {1: 'and',
#  2: 'to',
#  3: 'in',
#  4: 'experience',
#  5: 'with',
#  6: 'of',
#  7: 'the',
#  8: 'or',
#  9: 'a',
#  10: 'ability',
#  11: 'business',
#  12: 'for',
#  13: 'as',
#  14: 'skills',
#  15: 'management',
#  16: 'work',
#  17: 'degree',
#  18: 'technical',
#  19: 'on',
#  20: 'google',
#  21: 'product',
#  22: 'equivalent',
#  23: 'teams',
#  24: 'sales',
#  25: 'practical',
#  26: 'data',
#  27: 'cloud',
#  28: 'team',
#  29: 'years',
#  30: 'customer',
#  31: 'bs',
#  32: 'working',
#  33: 'ba',
#  34: 'develop',
#  35: 'marketing',
#  36: 'design',
#  37: 'partners',
#  38: 'manage',
#  39: 'an',
#  40: 'related',
#  41: 'engineering',
#  42: 'including',
#  43: 'strategic',
#  44: 'development',
#  45: 'partner',
#  46: 'drive',
#  47: 'communication',
#  48: 'environment',
#  49: 'demonstrated',
#  50: 'cross',
#  51: 'that',
#  52: 'across',
#  53: 'technology',
#  54: 'support',
#  55: 'solutions',
#  56: 'relationships',
#  57: 'excellent',
#  58: 'field',
#  59: 'functional',
#  60: 'our',
#  61: 'projects',
#  62: 'program',
#  63: 'strong',
#  64: 'analytical',
#  65: 'be',
#  66: 'products',
#  67: 'new',
#  68: 'analysis',
#  69: 'project',
#  70: 'at',
#  71: 'provide',
#  72: 'industry',
#  73: 'build',
#  74: 'complex',
#  75: 'customers',
#  76: 'strategy',
#  77: 'their',
#  78: 'computer',
#  79: 'knowledge',
#  80: 'science',
#  81: 'understanding',
#  82: 'software',
#  83: 'lead',
#  84: 'stakeholders',
#  85: 'identify',
#  86: 'service',
#  87: 'other',
#  88: 'operations',
#  89: 'systems',
#  90: 'managing',
#  91: 'through',
#  92: 'multiple',
#  93: 'internal',
#  94: 'platform',
#  95: 'effective',
#  96: 'opportunities',
#  97: 'market',
#  98: 'technologies',
#  99: 'by',
#  100: 'research',
#  101: 'all',
#  102: 'deliver',
#  103: 'process',
#  104: 'relevant',
#  105: 'g',
#  106: 'your',
#  107: 'key',
#  108: 'performance',
#  109: 'goals',
#  110: 'from',
#  111: 'e',
#  112: 'consulting',
#  113: 'global',
#  114: 'client',
#  115: 'ensure',
#  116: 'advertising',
#  117: 'processes',
#  118: 'high',
#  119: 'write',
#  120: 'leadership',
#  121: 'speak',
#  122: 'are',
#  123: 'time',
#  124: 'within',
#  125: 'implement',
#  126: 'issues',
#  127: 'english',
#  128: 'level',
#  129: 'written',
#  130: 'organizational',
#  131: 'media',
#  132: 'fluently',
#  133: '2018',
#  134: 'programs',
#  135: 'idiomatically',
#  136: 'strategies',
#  137: 'clients',
#  138: 'services',
#  139: 'effectively',
#  140: 'mobile',
#  141: 'interpersonal',
#  142: 'help',
#  143: 'such',
#  144: 'fast',
#  145: 'initiatives',
#  146: 'tools',
#  147: 'web',
#  148: 'user',
#  149: 'communicate',
#  150: 'well',
#  151: 'understand',
#  152: 'mba',
#  153: 'paced',
#  154: 'etc',
#  155: 'large',
#  156: 'google’s',
#  157: 'growth',
#  158: 'infrastructure',
#  159: 'developing',
#  160: 'improve',
#  161: 'solving',
#  162: 'problem',
#  163: 'recommendations',
#  164: 'interest',
#  165: 'planning',
#  166: 'insights',
#  167: 'account',
#  168: 'plans',
#  169: 'role',
#  170: 'needs',
#  171: 'legal',
#  172: 'full',
#  173: 'both',
#  174: 'communications',
#  175: 'quality',
#  176: 'based',
#  177: 'operational',
#  178: 'requirements',
#  179: 'activities',
#  180: 'external',
#  181: 'online',
#  182: 'them',
#  183: 'platforms',
#  184: 'create',
#  185: 'enterprise',
#  186: 'verbal',
#  187: 'maintain',
#  188: 'influence',
#  189: 'analytics',
#  190: 'using',
#  191: '5',
#  192: 'c',
#  193: 'best',
#  194: 'into',
#  195: 'it',
#  196: 'building',
#  197: 'creative',
#  198: 'scale',
#  199: 'organization',
#  200: 'presentations',
#  201: 'finance',
#  202: 'up',
#  203: 'leading',
#  204: 'information',
#  205: 'is',
#  206: 'problems',
#  207: 'between',
#  208: 'closely',
#  209: 'while',
#  210: 'implementation',
#  211: 'make',
#  212: 'digital',
#  213: 'presentation',
#  214: "master's",
#  215: 'executive',
#  216: 'levels',
#  217: 'practices',
#  218: '10',
#  219: 'training',
#  220: 'internship',
#  221: 'results',
#  222: 'collaborate',
#  223: 'end',
#  224: 'analyze',
#  225: 'content',
#  226: 'detail',
#  227: 'complete',
#  228: 'define',
#  229: 'security',
#  230: 'proven',
#  231: 'python',
#  232: 'areas',
#  233: 'able',
#  234: 'solution',
#  235: 'corporate',
#  236: 'trends',
#  237: '2019',
#  238: 'track',
#  239: 'metrics',
#  240: 'required',
#  241: 'specific',
#  242: 'financial',
#  243: 'interaction',
#  244: 'challenges',
#  245: 'travel',
#  246: 'highly',
#  247: 'senior',
#  248: 'plan',
#  249: 'how',
#  250: 'accounting',
#  251: 'impact',
#  252: 'one',
#  253: 'execute',
#  254: 'system',
#  255: 'existing',
#  256: 'can',
#  257: 'portfolio',
#  258: 'agency',
#  259: "google's",
#  260: 'events',
#  261: 'delivery',
#  262: "bachelor's",
#  263: 'search',
#  264: 'managers',
#  265: 'expertise',
#  266: 'computing',
#  267: 'sql',
#  268: 'internet',
#  269: 'people',
#  270: 'quantitative',
#  271: 'regional',
#  272: '4',
#  273: 'javascript',
#  274: 'agreements',
#  275: 'campaigns',
#  276: 'optimize',
#  277: 'engage',
#  278: 'visual',
#  279: 'consumer',
#  280: 'ideas',
#  281: 'execution',
#  282: 'value',
#  283: 'include',
#  284: 'given',
#  285: 'audiences',
#  286: 'statistics',
#  287: 'company',
#  288: 'channel',
#  289: 'record',
#  290: 'self',
#  291: 'responsibilities',
#  292: 'supply',
#  293: 'changing',
#  294: 'writing',
#  295: 'date',
#  296: 'resources',
#  297: 'interns',
#  298: '3',
#  299: 'iaas',
#  300: 'change',
#  301: 'responsibility',
#  302: 'ad',
#  303: 'serve',
#  304: 'advocate',
#  305: 'success',
#  306: 'solve',
#  307: 'application',
#  308: 'scalable',
#  309: 'more',
#  310: 'paas',
#  311: 'ongoing',
#  312: 'providing',
#  313: 'currently',
#  314: 'suite',
#  315: 'achieve',
#  316: 'oriented',
#  317: 'delivering',
#  318: 'compliance',
#  319: 'reviews',
#  320: 'priorities',
#  321: 'various',
#  322: 'engineers',
#  323: 'towards',
#  324: 'environments',
#  325: 'brand',
#  326: 'year',
#  327: 'java',
#  328: 'executives',
#  329: 'assigned',
#  330: 'june',
#  331: 'prioritize',
#  332: 'use',
#  333: 'conduct',
#  334: 'meet',
#  335: 'production',
#  336: 'term',
#  337: 'facing',
#  338: 'partnerships',
#  339: 'judgment',
#  340: 'hardware',
#  341: 'reporting',
#  342: 'day',
#  343: 'december',
#  344: 'present',
#  345: 'range',
#  346: 'agencies',
#  347: 'go',
#  348: 'collaboration',
#  349: 'saas',
#  350: 'background',
#  351: 'relationship',
#  352: 'policies',
#  353: 'supporting',
#  354: 'practice',
#  355: 'attention',
#  356: 'must',
#  357: 'operate',
#  358: 'act',
#  359: 'local',
#  360: 'risk',
#  361: 'chain',
#  362: 'will',
#  363: 'independent',
#  364: 'take',
#  365: 'order',
#  366: '2',
#  367: 'big',
#  368: 'ux',
#  369: 'prepare',
#  370: 'graduating',
#  371: 'public',
#  372: 'concepts',
#  373: 'vendor',
#  374: 'hr',
#  375: 'approach',
#  376: 'driven',
#  377: 'familiarity',
#  378: 'network',
#  379: 'united',
#  380: 'states',
#  381: 'policy',
#  382: 'statistical',
#  383: 'successful',
#  384: 'graduation',
#  385: 'standards',
#  386: 'professional',
#  387: 'talent',
#  388: 'multi',
#  389: 'long',
#  390: 'members',
#  391: 'language',
#  392: 'improvements',
#  393: 'focus',
#  394: 'advice',
#  395: '6',
#  396: 'languages',
#  397: 'deep',
#  398: 'vendors',
#  399: 'integration',
#  400: 'ecosystem',
#  401: 'focused',
#  402: 'thinking',
#  403: 'models',
#  404: 'about',
#  405: 'effectiveness',
#  406: 'objectives',
#  407: 'capabilities',
#  408: 'enrolled',
#  409: 'findings',
#  410: 'fields',
#  411: 'test',
#  412: 'have',
#  413: 'competitive',
#  414: 'documentation',
#  415: 'functionally',
#  416: 'programming',
#  417: 'quickly',
#  418: 'manager',
#  419: 'architectures',
#  420: 'passion',
#  421: 'may',
#  422: 'territory',
#  423: 'partnership',
#  424: 'applications',
#  425: 'trusted',
#  426: 'base',
#  427: 'simultaneously',
#  428: 'perform',
#  429: 'making',
#  430: 'adoption',
#  431: 'student',
#  432: 'non',
#  433: 'human',
#  434: 'basis',
#  435: 'week',
#  436: 'pipeline',
#  437: 'start',
#  438: 'reports',
#  439: 'investment',
#  440: 'contribute',
#  441: 'education',
#  442: 'cycle',
#  443: 'feedback',
#  444: 'advertisers',
#  445: 'following',
#  446: 'handle',
#  447: 'maintaining',
#  448: 'android',
#  449: 'critical',
#  450: 'resolve',
#  451: 'code',
#  452: 'contact',
#  453: 'variety',
#  454: 'law',
#  455: 'users',
#  456: 'when',
#  457: 'efficiency',
#  458: 'risks',
#  459: 'returning',
#  460: 'demonstrate',
#  461: 'implementing',
#  462: 'outstanding',
#  463: 'html',
#  464: 'techniques',
#  465: 'groups',
#  466: 'advise',
#  467: 'grow',
#  468: 'individual',
#  469: 'accounts',
#  470: 'review',
#  471: 'leaders',
#  472: 'guidance',
#  473: 'cost',
#  474: 'meaningful',
#  475: 'decision',
#  476: 'engagement',
#  477: 'innovative',
#  478: 'capacity',
#  479: 'broad',
#  480: 'any',
#  481: 'ms',
#  482: 'area',
#  483: 'campaign',
#  484: 'successfully',
#  485: 'modeling',
#  486: 'authorization',
#  487: 'coordinate',
#  488: 'features',
#  489: 'staffing',
#  490: 'video',
#  491: 'similar',
#  492: 'overall',
#  493: 'space',
#  494: 'status',
#  495: 'establish',
#  496: 'optimization',
#  497: 'designing',
#  498: 'setting',
#  499: 'efforts',
#  500: 'aspects',
#  501: 'architecture',
#  502: 'opportunity',
#  503: 'measurement',
#  504: 'proactively',
#  505: 'needed',
#  506: 'dynamic',
#  507: 'learn',
#  508: 'detailed',
#  509: 'functions',
#  510: 'direct',
#  511: 'others',
#  512: 'ways',
#  513: 'influencing',
#  514: 'emerging',
#  515: 'methodologies',
#  516: 'contribution',
#  517: 'potential',
#  518: 'necessary',
#  519: 'set',
#  520: 'they',
#  521: 'who',
#  522: 'principles',
#  523: 'documents',
#  524: 'learning',
#  525: 'different',
#  526: 'compelling',
#  527: 'share',
#  528: 'clear',
#  529: 'methods',
#  530: 'testing',
#  531: 'out',
#  532: 'expected',
#  533: 'phd',
#  534: 'matters',
#  535: 'creating',
#  536: 'offerings',
#  537: 'pursuing',
#  538: 'developer',
#  539: 'administration',
#  540: 'networking',
#  541: 'minimum',
#  542: 'office',
#  543: 'collaboratively',
#  544: 'wide',
#  545: 'ambiguous',
#  546: 'control',
#  547: 'improvement',
#  548: 'studies',
#  549: 'third',
#  550: 'retail',
#  551: 'upon',
#  552: 'around',
#  553: 'against',
#  554: 'messaging',
#  555: 'decisions',
#  556: 'assist',
#  557: 'linux',
#  558: 'requests',
#  559: 'sets',
#  560: 'materials',
#  561: '8',
#  562: 'emea',
#  563: 'youtube',
#  564: 'hiring',
#  565: 'during',
#  566: 'consultative',
#  567: 'advanced',
#  568: 'determined',
#  569: 'direction',
#  570: 'social',
#  571: 'changes',
#  572: 'troubleshooting',
#  573: 'which',
#  574: 'launch',
#  575: 'constantly',
#  576: 'leverage',
#  577: 'point',
#  578: 'manufacturing',
#  579: 'completing',
#  580: 'recruiting',
#  581: 'distributed',
#  582: 'responsible',
#  583: 'apply',
#  584: 'solid',
#  585: 'coordination',
#  586: 'lot',
#  587: 'increase',
#  588: 'tax',
#  589: 'flexibility',
#  590: 'beginning',
#  591: 'think',
#  592: 'vertical',
#  593: 'so',
#  594: 'experiences',
#  595: 'firm',
#  596: 'identifying',
#  597: 'via',
#  598: 'please',
#  599: 'adwords',
#  600: 'quarterly',
#  601: 'thorough',
#  602: 'designs',
#  603: 'resume',
#  604: 'throughout',
#  605: 'intelligence',
#  606: 'r',
#  607: 'international',
#  608: 'independently',
#  609: 'consult',
#  610: 'analyses',
#  611: 'organized',
#  612: 'serving',
#  613: 'engineer',
#  614: 'analyzing',
#  615: 'life',
#  616: 'briefings',
#  617: 'navigate',
#  618: '12',
#  619: 'diverse',
#  620: 'meetings',
#  621: 'evaluate',
#  622: 'graphic',
#  623: 'party',
#  624: 'entire',
#  625: 'selling',
#  626: 'proficiency',
#  627: 'apps',
#  628: 'site',
#  629: 'vision',
#  630: 'consistently',
#  631: 'oral',
#  632: 'sap',
#  633: 'major',
#  634: 'structure',
#  635: 'tracking',
#  636: 'display',
#  637: 'starter',
#  638: 'candidates',
#  639: 'strategically',
#  640: 'commercial',
#  641: 'scripting',
#  642: 'evolving',
#  643: 'shape',
#  644: 'directly',
#  645: 'concept',
#  646: 'leveraging',
#  647: 'core',
#  648: 'leads',
#  649: 'driving',
#  650: 'sourcing',
#  651: 'organizations',
#  652: 'position',
#  653: 'close',
#  654: 'consistent',
#  655: 'css',
#  656: 'buying',
#  657: 'region',
#  658: 'email',
#  659: 'if',
#  660: 'educate',
#  661: 'primary',
#  662: 'channels',
#  663: 'audience',
#  664: 'automation',
#  665: 'completion',
#  666: 'combined',
#  667: 'action',
#  668: 'top',
#  669: 'architect',
#  670: 'ensuring',
#  671: 'demand',
#  672: '11',
#  673: 'prototype',
#  674: 'doubleclick',
#  675: 'appropriate',
#  676: 'integrations',
#  677: 'tech',
#  678: 'challenging',
#  679: 'satisfaction',
#  680: 'relations',
#  681: 'german',
#  682: 'hands',
#  683: 'assets',
#  684: 'part',
#  685: 'machine',
#  686: 'database',
#  687: 'exceptional',
#  688: 'landscape',
#  689: 'advisor',
#  690: 'collaborating',
#  691: 'first',
#  692: 'good',
#  693: 'house',
#  694: 'integrators',
#  695: 'interact',
#  696: 'right',
#  697: 'thought',
#  698: 'negotiation',
#  699: 'joint',
#  700: '7',
#  701: 'agreement',
#  702: 'maximize',
#  703: 'crm',
#  704: 'engagements',
#  705: 'contract',
#  706: 'bid',
#  707: 'expert',
#  708: 'get',
#  709: 'current',
#  710: 'electrical',
#  711: 'businesses',
#  712: 'sense',
#  713: 'produce',
#  714: 'deliverables',
#  715: 'defined',
#  716: 'this',
#  717: 'pr',
#  718: 'usability',
#  719: 'interface',
#  720: 'behavior',
#  721: 'ambiguity',
#  722: 'comprehensive',
#  723: 'audit',
#  724: 'motivated',
#  725: 'goal',
#  726: 'thinker',
#  727: 'voice',
#  728: 'event',
#  729: 'procedures',
#  730: 'regarding',
#  731: 'presenting',
#  732: 'storage',
#  733: 'promote',
#  734: 'timelines',
#  735: 'mathematics',
#  736: 'standard',
#  737: 'launches',
#  738: 'communicating',
#  739: 'taking',
#  740: 'each',
#  741: 'generation',
#  742: 'proposition',
#  743: 'designers',
#  744: 'candidate',
#  745: 'productivity',
#  746: 'skill',
#  747: 'educational',
#  748: 'operating',
#  749: 'markets',
#  750: 'determine',
#  751: 'inform',
#  752: 'qualify',
#  753: 'proactive',
#  754: 'accountability',
#  755: 'investigations',
#  756: 'intern',
#  757: 'leader',
#  758: 'effort',
#  759: 'you',
#  760: 'assess',
#  761: 'university',
#  762: 'internally',
#  763: 'spreadsheet',
#  764: 'align',
#  765: 'member',
#  766: 'priority',
#  767: 'resource',
#  768: 'coach',
#  769: 'creation',
#  770: 'interview',
#  771: 'consultant',
#  772: 'actionable',
#  773: 'industrial',
#  774: 'common',
#  775: 'associated',
#  776: 'collaborative',
#  777: 'july',
#  778: 'salesforce',
#  779: 'live',
#  780: 'personal',
#  781: 'databases',
#  782: 'previous',
#  783: 'competing',
#  784: 'sciences',
#  785: 'highlight',
#  786: 's',
#  787: 'regular',
#  788: 'touch',
#  789: 'cultivate',
#  790: 'consultation',
#  791: 'controls',
#  792: 'supplier',
#  793: 'continuous',
#  794: 'monitor',
#  795: 'initiative',
#  796: 'own',
#  797: 'resolution',
#  798: 'ios',
#  799: 'guide',
#  800: 'future',
#  801: 'these',
#  802: 'address',
#  803: 'offer',
#  804: 'task',
#  805: 'protocols',
#  806: 'discussions',
#  807: 'psychology',
#  808: 'applied',
#  809: 'device',
#  810: 'partnering',
#  811: 'interested',
#  812: 'accurately',
#  813: 'colleagues',
#  814: 'participate',
#  815: 'keep',
#  816: 'lifecycle',
#  817: 'tailor',
#  818: 'privacy',
#  819: 'commit',
#  820: 'sensitive',
#  821: 'frameworks',
#  822: 'unix',
#  823: 'automate',
#  824: 'stakeholder',
#  825: 'press',
#  826: 'productive',
#  827: 'roles',
#  828: 'schedule',
#  829: 'proof',
#  830: 'demonstrations',
#  831: 'white',
#  832: 'we',
#  833: 'innovation',
#  834: 'impeccable',
#  835: 'difficult',
#  836: 'exchange',
#  837: 'matter',
#  838: 'timely',
#  839: 'country',
#  840: 'survey',
#  841: 'conducting',
#  842: 'proposals',
#  843: 'advertiser',
#  844: 'become',
#  845: 'identity',
#  846: 'access',
#  847: 'particular',
#  848: 'government',
#  849: 'balancing',
#  850: 'months',
#  851: 'healthcare',
#  852: 'not',
#  853: 'subject',
#  854: 'motivation',
#  855: 'prioritizing',
#  856: 'model',
#  857: 'distinctive',
#  858: 'distribution',
#  859: 'merchandising',
#  860: 'structures',
#  861: 'interests',
#  862: 'forecast',
#  863: 'i',
#  864: 'updates',
#  865: 'students',
#  866: 'weeks',
#  867: 'certification',
#  868: '2020',
#  869: 'slide',
#  870: 'papers',
#  871: 'dynamics',
#  872: 'spanish',
#  873: 'bring',
#  874: 'experiments',
#  875: 'motivate',
#  876: 'activity',
#  877: 'traditional',
#  878: 'deadlines',
#  879: 'actively',
#  880: 'domain',
#  881: 'app',
#  882: 'acquisition',
#  883: 'hci',
#  884: 'procurement',
#  885: 'open',
#  886: 'sure',
#  887: 'master',
#  888: 'enhance',
#  889: 'report',
#  890: 'networks',
#  891: 'implementations',
#  892: 'drivers',
#  893: 'architecting',
#  894: 'ip',
#  895: 'input',
#  896: 'providers',
#  897: 'deployment',
#  898: 'health',
#  899: 'response',
#  900: 'ownership',
#  901: 'coaching',
#  902: 'matrixed',
#  903: 'ads',
#  904: 'growing',
#  905: 'style',
#  906: 'along',
#  907: 'measure',
#  908: 'sector',
#  909: 'efficient',
#  910: 'performing',
#  911: 'budgets',
#  912: 'two',
#  913: 'explore',
#  914: 'com',
#  915: 'liaison',
#  916: 'recruit',
#  917: 'budget',
#  918: 'forecasting',
#  919: 'wider',
#  920: 'play',
#  921: 'motion',
#  922: 'further',
#  923: '1',
#  924: 'phone',
#  925: 'generate',
#  926: 'acumen',
#  927: 'engaging',
#  928: 'visualization',
#  929: 'employment',
#  930: 'onsite',
#  931: 'september',
#  932: 'basic',
#  933: 'influential',
#  934: 'alignment',
#  935: 'rapidly',
#  936: 'tasks',
#  937: 'influencers',
#  938: 'after',
#  939: 'outside',
#  940: 'mandarin',
#  941: 'trial',
#  942: 'clearly',
#  943: 'give',
#  944: 'established',
#  945: 'economics',
#  946: 'those',
#  947: 'hoc',
#  948: 'annual',
#  949: 'lasting',
#  950: 'regulatory',
#  951: 'collect',
#  952: 'translate',
#  953: 'depth',
#  954: 'generating',
#  955: 'inside',
#  956: 'speed',
#  957: 'property',
#  958: 'state',
#  959: 'safety',
#  960: 'dashboards',
#  961: 'scaled',
#  962: 'regions',
#  963: 'comfort',
#  964: 'willingness',
#  965: 'responses',
#  966: 'whiteboard',
#  967: 'apis',
#  968: 'broader',
#  969: 'stage',
#  970: 'reference',
#  971: 'significant',
#  972: 'topics',
#  973: 'analysts',
#  974: 'speaking',
#  975: 'organize',
#  976: 'comfortable',
#  977: 'real',
#  978: 'increasing',
#  979: 'employee',
#  980: 'function',
#  981: 'readiness',
#  982: 'mechanical',
#  983: 'electronics',
#  984: 'points',
#  985: 'prior',
#  986: 'load',
#  987: 'intellectual',
#  988: 'agile',
#  989: 'rfi',
#  990: 'integrity',
#  991: 'includes',
#  992: 'staff',
#  993: 'progress',
#  994: 'suggestions',
#  995: 'prototypes',
#  996: 'executing',
#  997: 'programmatic',
#  998: 'entertainment',
#  999: 'devices',
#  1000: 'story',
#  ...}

# %%
get_nearest_words('google')
# Out:
# (['multiple',
#   'unlock',
#   'periodically',
#   '2109',
#   'hungarian',
#   'format',
#   'investigations1',
#   'barriers',
#   'targeting',
#   'on'],
#  ['an',
#   'running',
#   'deploy',
#   'lotus',
#   'routed',
#   'obstacles',
#   'portfolioonline',
#   'seek',
#   'cohorts',
#   'uat'])
