# %%
from sklearn.datasets import load_iris

iris = load_iris()

# %%
data1 = iris.data[:,0:2]
data1.shape
# Out:
# (150, 2)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data1[:,0],data1[:,1])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

data1_scaled = scaler.fit_transform(data1)
data1_scaled.shape
# Out:
# (150, 2)

# %%
plt.scatter(data1_scaled[:,0],data1_scaled[:,1])

# %%
import numpy as np

# %%
np.cov(data1.T)
# Out:
# array([[ 0.68569351, -0.03926846],
#        [-0.03926846,  0.18800403]])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

# %%
components = pca.fit_transform(data1)

# %%
plt.scatter(components[:,0],components[:,1])

# %%
scaler2 = StandardScaler()
components_scaled = scaler2.fit_transform(components)

# %%
plt.scatter(components[:,0],components[:,1])

# %%
comp_cov = np.cov(components.T)
comp_cov
# Out:
# array([[ 6.88772801e-01, -3.92167623e-17],
#        [-3.92167623e-17,  1.84924738e-01]])

# %%
np.linalg.eig(comp_cov)
# Out:
# (array([0.6887728 , 0.18492474]), array([[1.00000000e+00, 7.78345004e-17],
#         [0.00000000e+00, 1.00000000e+00]]))

# %%
np.dot(np.linalg.eig(comp_cov)[1],
# Out:
# array([[1.00000000e+00, 7.78345004e-17],
#        [0.00000000e+00, 1.00000000e+00]])

# %% [markdown]
# # PCA

# %%
import numpy as np
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
import matplotlib.cm as cm

# %%
digits = load_digits()
data = digits.data

# %%
n_samples, n_features = data.shape

# %%
n_digits = len(np.unique(digits.target))

# %%
labels = digits.target

# %%
pca = PCA(n_components = 64)
data_r = pca.fit_transform(data)

# %%
print('explained variance ratio (first two components): %s' %str(pca.explained_variance_ratio_))
print('sum of explained variance (first two components): %s' %str(sum(pca.explained_variance_ratio_)))
# Out:
# explained variance ratio (first two components): [1.48905936e-01 1.36187712e-01 1.17945938e-01 8.40997942e-02
#  5.78241466e-02 4.91691032e-02 4.31598701e-02 3.66137258e-02
#  3.35324810e-02 3.07880621e-02 2.37234084e-02 2.27269657e-02
#  1.82186331e-02 1.77385494e-02 1.46710109e-02 1.40971560e-02
#  1.31858920e-02 1.24813782e-02 1.01771796e-02 9.05617439e-03
#  8.89538461e-03 7.97123157e-03 7.67493255e-03 7.22903569e-03
#  6.95888851e-03 5.96081458e-03 5.75614688e-03 5.15157582e-03
#  4.89539777e-03 4.28887968e-03 3.73606048e-03 3.53274223e-03
#  3.36683986e-03 3.28029851e-03 3.08320884e-03 2.93778629e-03
#  2.56588609e-03 2.27742397e-03 2.22277922e-03 2.11430393e-03
#  1.89909062e-03 1.58652907e-03 1.51159934e-03 1.40578764e-03
#  1.16622290e-03 1.07492521e-03 9.64053065e-04 7.74630271e-04
#  5.57211553e-04 4.04330693e-04 2.09916327e-04 8.24797098e-05
#  5.25149980e-05 5.05243719e-05 3.29961363e-05 1.24365445e-05
#  7.04827911e-06 3.01432139e-06 1.06230800e-06 5.50074587e-07
# ...

# %%
data.shape
# Out:
# (1797, 64)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale = StandardScaler()

# %%
data_scaled = scale.fit_transform(data)

cov_matrix = np.cov(data_scaled)

# %%
comp_scaled = scale.fit_transform(data_r)

cov_matrix_comp = np.cov(data_r)

# %%
cov_matrix_comp
# Out:
# array([[ 15.4356854 , -10.72084098,  -5.01466029, ...,  -4.16988205,
#           4.41535011,  -2.19087392],
#        [-10.72084098,  17.72026291,   5.60751846, ...,   5.21731874,
#          -2.24453053,  -3.15777961],
#        [ -5.01466029,   5.60751846,  20.59659393, ...,   6.63269445,
#          -2.76480122,   2.62331317],
#        ...,
#        [ -4.16988205,   5.21731874,   6.63269445, ...,  15.99998911,
#          -0.07665271,   9.05661293],
#        [  4.41535011,  -2.24453053,  -2.76480122, ...,  -0.07665271,
#          14.79370307,   2.7127091 ],
#        [ -2.19087392,  -3.15777961,   2.62331317, ...,   9.05661293,
#           2.7127091 ,  15.19330748]])
