# %% [markdown]
# Weight spaces -
#
# - https://stackoverflow.com/questions/22121469/geometric-representation-of-perceptrons-artificial-neural-networks
# - https://habr.com/post/324736/

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %matplotlib notebook

# %%
x1 = np.arange(-1,1,0.01)
x2 = np.arange(-1,1,0.01)

W1 = 0.3
W2 = 0.5
B = 0.5

X1, X2 = np.meshgrid(x1,x2)

Y = W1*X1 + W2*X2 + B

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_wireframe(X1,X2,Y)
# Out:
# <img src="data:image/png;base64,..." width="811.5">

# %%
w1 = np.arange(-1,1,0.01)
w2 = np.arange(-1,1,0.01)

W1,W2 = np.meshgrid(w1,w2)

X1 = [0.3,0.2,1]
X2 = [0.5,0.8,0.8]
B = 0.5


fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')

for i in range(3):
    Y = W1*X1[i] + W2*X2[i] + B
    ax.plot_wireframe(W1,W2,Y)
# Out:
# <img src="data:image/png;base64,..." width="770">

# %%
x1 = np.arange(-10,10,0.01)
x2_lin = 0.4*x1+0.2
x2_sig = 1/(1+np.exp(-1*x2_lin))

plt.plot(x1,x2_sig)
