# %% [markdown]
# # Interesting 3D Plots

# %%
import numpy as np
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import math

# %matplotlib notebook

# %%
# Symmetric Waves
x = np.arange(-150,150,10)
y = np.arange(-150,150,10)
X,Y = np.meshgrid(x,y)
R = np.sin(5*X)*np.cos(5*Y)/5

Z = R
fig1 = plt.figure()
ax1 = fig1.add_subplot(111,projection='3d')
ax1.plot_surface(X,Y,Z,cmap='coolwarm')
# Out:
# <img src="data:image/png;base64,..." width="975">

# %%
# Ripples
x = np.arange(-1,1,0.01)
y = np.arange(-1,1,0.01)
X,Y = np.meshgrid(x,y)
R = np.sin(10*(X**2 + Y**2))/10

Z = R
fig2 = plt.figure()
ax2 = fig2.add_subplot(111,projection='3d')
ax2.plot_surface(X,Y,Z,cmap='coolwarm')
# Out:
# <img src="data:image/png;base64,..." width="978.5">

# %%
# Tunnel
x = np.arange(-150,150,10)
y = np.arange(-150,150,10)
X,Y = np.meshgrid(x,y)
R = (1/(15*(X**2+Y**2)))

Z = R
fig3 = plt.figure()
ax3 = fig3.add_subplot(111,projection='3d')
ax3.plot_wireframe(X,Y,Z)
# Out:
# /Users/akshay/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """
# <img src="data:image/png;base64,..." width="952">

# %%
# Tunnel
x = np.arange(-150,150,10)
y = np.arange(-150,150,10)
X,Y = np.meshgrid(x,y)
R = (X**2-Y**2)

Z = R
fig = plt.figure()
ax = fig3.add_subplot(111,projection='3d')
ax.plot_surface(X,Y,Z,cmap='coolwarm')
# Out:
# <img src="data:image/png;base64,..." width="718">

# %%
x1 = np.arange(-100,100,1)
x2 = np.arange(-100,100,1)
X,Y = np.meshgrid(x1,x2)

Z = R
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(X,Y,Z)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import cv2

img = cv2.imread('mainlogo.png',cv2.IMREAD_GRAYSCALE)
ret,mask = cv2.threshold(img,220,255,cv2.THRESH_BINARY)

#b,g,r = cv2.split(img)
#img_new = cv2.merge([r,g,b])

px,py = mask.shape 

x = np.arange(0,px,1)
y = np.arange(0,py,1)

X,Y = np.meshgrid(x,y)

Z = mask
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_wireframe(X,Y,Z)
# Out:
# <img src="data:image/png;base64,..." width="911">

# %%
ret
# Out:
# 220.0
